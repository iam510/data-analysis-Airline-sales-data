# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
plt.rcParams['font.family'] = 'SimSun'
data = pd.read_csv('../newData.csv',encoding='gbk')

# 提取特征和目标变量
features = data[['月份', '日期', '星期几', '季节', '节假日']]
target = data['航线金额']

# 数据拆分为训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, shuffle=False)
# 创建GBDT回归模型
model = GradientBoostingRegressor()

# 训练模型
model.fit(X_train, y_train)

# 在测试集上进行预测
y_pred = model.predict(X_test)

# 计算均方根误差（RMSE）
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error (RMSE):", rmse)

# 计算均方误差（MSE）
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# 计算平均绝对误差（MAE）
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)

# 计算决定系数（R^2）
r2 = r2_score(y_test, y_pred)
print("R^2 Score:", r2)
# Out:
# Root Mean Squared Error (RMSE): 242125.15298603606
# Mean Squared Error (MSE): 58624589708.51137
# Mean Absolute Error (MAE): 206738.69575930724
# R^2 Score: -0.03793022963719772
# D:\anaconda\envs\datawym\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# 绘制折线图
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Sample')
plt.ylabel('航线金额')
plt.title('Actual vs Predicted')
plt.legend()
plt.show()
