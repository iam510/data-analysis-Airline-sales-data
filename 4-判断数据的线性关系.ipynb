# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 读取数据
data = pd.read_csv('data.csv',encoding='gbk')
data
# Out:
#            航班日期        航线金额
# 0    2023-01-01   168320.00
# 1    2023-01-02   222618.00
# 2    2023-01-03   304062.00
# 3    2023-01-04   377547.00
# 4    2023-01-05   297465.00
# ..          ...         ...
# 360  2023-12-27   668665.35
# 361  2023-12-28   732326.64
# 362  2023-12-29  1040086.00
# 363  2023-12-30   740359.38
# 364  2023-12-31   503901.69
#
# [365 rows x 2 columns]

# %%
# 绘制散点图
plt.scatter(data['航班日期'], data['航线金额'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot')
plt.show()

# %%
# 将'航班日期'列转换为日期时间类型
data['航班日期'] = pd.to_datetime(data['航班日期'])

# 计算相关系数
correlation = data['航班日期'].corr(data['航线金额'])
print('Correlation coefficient:', correlation)
# Out:
# Correlation coefficient: nan
# D:\anaconda\envs\datawym\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# D:\anaconda\envs\datawym\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# 检查每列中的缺失值数量
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# 航班日期    365
# 航线金额      0
# dtype: int64
