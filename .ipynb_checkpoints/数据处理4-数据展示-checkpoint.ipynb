# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'SimSun'

# 读取.csv文件
df = pd.read_csv('airlineSalesS.csv',encoding='gbk')

# 将日期列转换为日期类型
df['航班日期'] = pd.to_datetime(df['航班日期'])

# 按月份计算销售额总和
monthly_sales = df.groupby(df['航班日期'].dt.to_period('M'))['实际销售额（sale_volume）'].sum()
# 按周计算销售额总和
weekly_sales = df.resample('W', on='航班日期')['实际销售额（sale_volume）'].sum()
# 按日期计算销售额总和
daily_sales = df.groupby(df['航班日期'])['实际销售额（sale_volume）'].sum()

# 将Period类型转换为字符串格式
monthly_sales.index = monthly_sales.index.astype(str)

# %%
plt.plot(monthly_sales.index, monthly_sales)
plt.xlabel('月份')
plt.ylabel('销售额')
plt.title('每月销售额变化')
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(monthly_sales.index.astype(str), monthly_sales)
plt.xlabel('月份')
plt.ylabel('销售额')
plt.title('每月销售额变化')
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(weekly_sales.index, weekly_sales)
plt.xlabel('周')
plt.ylabel('销售额')
plt.title('每周销售额变化')
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(weekly_sales.index, weekly_sales)
plt.xlabel('周')
plt.ylabel('销售额')
plt.title('每周销售额变化')
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(daily_sales.index, daily_sales)
plt.xlabel('日期')
plt.ylabel('销售额')
plt.title('每天销售额变化')
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(daily_sales.index, daily_sales)
plt.xlabel('日期')
plt.ylabel('销售额')
plt.title('每天销售额变化')
plt.xticks(rotation=45)
plt.show()
